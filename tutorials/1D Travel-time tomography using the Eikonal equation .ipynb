# %% [markdown]
# # Traveltime tomography using the Eikonal equation
#
# @Author: Ettore Biondi - ebiondi@caltech.edu

# %% [markdown]
# In this notebook, we provide an example of how to solve a traveltime tomography problem using the solution to the Eikonal equation. This equation can be written as follows:
# \begin{eqnarray}
# \nabla \tau(\mathbf{x}) \cdot \nabla \tau(\mathbf{x})= \|\nabla \tau(\mathbf{x})\|^2 = \frac{1}{v^2(\mathbf{x})},
# \end{eqnarray}
# where $v$ is the wave speed, $\tau$ is the traveltime, and $\mathbf{x}$ denotes the spatial variables (i.e., $x$, $y$, and $z$). To solve the previous partial-differential equation (PDE), we employ the fast-marching method described by [Sethian (1996)](https://www.pnas.org/content/pnas/93/4/1591.full.pdf). The solution of the Eikonal equation depends non-linearly on the velocity parameter $v$. Hence, we express its discrete solution as follows:
# \begin{eqnarray}
# \pmb{\tau} = \mathbf{f}(\mathbf{v}).
# \end{eqnarray}
# The Jacobian $\mathbf{F}$ of the non-linear operator $\mathbf{f}$ obeys the following equation:
# \begin{eqnarray}
# 2[\nabla \tau(\mathbf{x})] \cdot [\nabla \delta\tau(\mathbf{x})] = \delta v(\mathbf{x}),
# \end{eqnarray}
# where $\delta\tau$ represents the traveltime perturbation due to the velocity perturbation $\delta v(\mathbf{x})$. The previous relation when discretized represents a linear system of equations that can be solved by forward substitution [Li et al. (2013)](https://pi.math.cornell.edu/~vlad/papers/DSR_Geophysics_2013.pdf).

# %%
import occamypy
import numpy as np
import os
import pkg_resources
import scipy.ndimage

# Plotting
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline
params = {
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 14, # fontsize for x and y labels (was 10)
    'axes.titlesize': 14,
    'font.size': 14,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'text.usetex':False
}
matplotlib.rcParams.update(params)
# Out:
# WARNING! DATAPATH not found. The folder /tmp will be used to write binary files

# %% [markdown]
# Let's start by implementing the fast-marching method to solve the non-linear PDE defined by the Eikonal equation.

# %%
# Functions for solving Eikonal equation in 1D
import operator
def sorting(tt, idx, ordering="a"):
    if ordering == "a":
        sorted_indices = np.argsort(tt[idx])
    elif ordering == "d":
        sorted_indices = np.argsort(-tt[idx])
    else:
        raise ValueError("Unknonw ordering: %s! Provide a or d for ascending or descending" % ordering)
    
    # Sorting indices
    idx_sort = [idx[id] for id in sorted_indices]
    return idx_sort
# Fast-Marching-Method (FMM) 
def FMM_tt(tt, vv, dx, status, trial_idx):
    """Function to perform fast-marching method"""
    nx = vv.shape[0]
    dx_inv = 1.0 / dx
    # Various necessary variables
    drxns = [-1, 1]
    nbrs = np.zeros(2, dtype=int)
    # FFM main loop
    while len(trial_idx) > 0:
        # Getting trial point with smallest traveltime
        active_idx = trial_idx.pop(0)
        status[active_idx] = 'k'

        # Creating indices of neighbouring points
        for idx in range(2):
            nbrs[idx] = active_idx + drxns[idx]

        # Loop over neighbourning points
        for idx, nb in enumerate(nbrs):
            # If point is outside the domain or has a known traveltime skip it
            if nb < 0 or nb >= nx or status[nb] == 'k':
                continue
            # Checking if the velocity model is positive
            if vv[nb] > 0:
                fdt = np.zeros(2)
                order = np.zeros(2)
                # Computing forward and backward derivatives from nb
                for ii in range(2):
                    nb_i = nb + drxns[ii]
                    if (nb_i < nx and 0 <= nb_i) and status[nb_i] == 'k':
                        order[ii] = 1
                        fdt[ii] = drxns[ii] * (tt[nb_i]-tt[nb]) * dx_inv
                    else:
                        order[ii] = 0
                # Selecting upwind derivative 
                if fdt[0] > -fdt[1]:
                    ii, idrx = 0, -1
                else:
                    ii, idrx = 1, 1
                # Selecting correct neighbourning point
                nb_i = nb + idrx
                # Updating traveltime by solving quadratic equation
                if order[ii] == 0:
                    a = b = c = 0
                else:
                    a = dx_inv * dx_inv
                    b = -2 * a * tt[nb_i]
                    c = tt[nb_i] * tt[nb_i] * a - 1.0 / (vv[nb]*vv[nb])
                # Point out of bounds
                if a == 0:
                    continue
                det = b*b - 4.0*a*c
                if det < 0.0:
                    # Negative determinant; set it to zero
                    new_t = - b / (2 * a)
                else:
                    new_t = (- b + np.sqrt(det)) / (2*a)
                # Checking if new traveltime is smaller than current estimate for this point
                if new_t < tt[nb]:
                    tt[nb] = new_t
                    if status[nb] == 'u':
                        trial_idx.append(nb)
                        status[nb] = 't'
                    else:
                        trial_idx = sorting(tt, trial_idx)
    return

# %% [markdown]
# Let's wrap this function into an operator class.

# %%
class EikonalTT_1D(occamypy.Operator):

    def __init__(self, vel, tt_data, dx, SouPos, RecPos):
        """1D Eikonal-equation traveltime prediction operator"""
        # Setting Domain and Range of the operator
        self.setDomainRange(vel, tt_data)
        # Setting acquisition geometry
        self.nSou = SouPos.shape[0]
        self.nRec = RecPos.shape[0]
        self.SouPos = SouPos.copy()
        self.RecPos = RecPos.copy()
        dataShape = tt_data.shape
        if dataShape[0] != self.nSou:
            raise ValueError("Number of sources inconsistent with traveltime vector (shape[0])")
        if dataShape[1] != self.nRec:
            raise ValueError("Number of receivers inconsistent with traveltime vector (shape[1])")
        self.dx = dx
        self.nx = vel.shape[0]

    def forward(self, add, model, data):
        """Forward non-linear traveltime prediction"""
        self.checkDomainRange(model, data)
        if not add: 
            data.zero()
        dataNd = data.getNdArray()
        velNd = model.getNdArray()
        # Initialization
        tt = np.zeros(self.nx)
        for iShot in range(self.nSou):
            # Initial conditions
            status = np.array(["u"] * self.nx) # All points are unknown
            tt.fill(np.inf)
            trial_idx = []
            # Initial conditions
            idx = self.SouPos[iShot]
            tt[idx] = 0.0
            status[idx] = 't' # Trial status
            trial_idx.append(idx)
            # Sorting trial time ascending order
            trial_idx = sorting(tt, trial_idx)
            FMM_tt(tt, velNd, self.dx, status, trial_idx)     
            for iRec in range(self.nRec):
                dataNd[iShot, iRec] += tt[self.RecPos[iRec]]
        return

# %% [markdown]
# We can now use this operator to compute some traveltimes using a simple velocity model in which a Gaussian anomaly is placed at its center.

# %%
# Sampling along the z direction
dx = 0.1
nx = 301
x = np.linspace(0,(nx-1)*dx,nx)
# Velocity model
vv = occamypy.VectorNumpy(np.zeros(nx))
vv.set(2.0)
vv.getNdArray()[:] -= 0.8 * np.exp(-0.5*(x-(nx/2.0)*dx)**2)

fig, ax = plt.subplots(figsize=(20,10))
ax.plot(x, vv.getNdArray(), lw=4)
ax.grid()
plt.xlabel("x [km]")
plt.ylabel("velocity [km/s]")
plt.ylim([1.0, 2.5])
ax.autoscale(enable=True, axis='x', tight=True)

# %% [markdown]
# Let's compute the traveltime for a single source and receivers at every grid point.

# %%
# Source/Receiver positions
SouPos = np.array([0])
RecPos = np.arange(0,nx)
# Data vector
tt_data = occamypy.VectorNumpy(np.zeros((SouPos.shape[0], RecPos.shape[0])))
# Setting Forward non-linear operator
Eik1D_Op = EikonalTT_1D(vv, tt_data, dx, SouPos, RecPos)
Eik1D_Op.forward(False, vv, tt_data)

# Plotting traveltime vector
fig, ax = plt.subplots(figsize=(20,10))
ax.plot(RecPos*dx, tt_data.getNdArray()[0, :], lw=4)
ax.grid()
plt.xlabel("x [km]")
plt.ylabel("Traveltime [s]")
plt.ylim([0.0, 16.0])
ax.autoscale(enable=True, axis='x', tight=True)

# %% [markdown]
# Let's implement and test the linearized Eikonal equation operators. Again we first define the functions to solve the forward and adjoint PDEs, and then we wrap it within an operator class.

# %%
def FMM_tt_lin_fwd(delta_v, delta_tt, vv, tt, dx):
    """Fast-marching method linearized forward in 1D"""
    nx = delta_v.shape[0]
    drxns = [-1, 1]
    nbrs = np.zeros(2, dtype=int)
    dx_inv = 1.0 / dx
    
    tt_idx = np.arange(nx)
    # Sorting traveltime in ascending order
    tt_idx = sorting(tt, tt_idx)
    
    # Scaling the velocity perturbation
    delta_v_scaled = - 2.0 * delta_v / (vv * vv * vv)

    # Looping over all indices to solve linear equations from increasing traveltime values
    for idx_t0 in tt_idx:
        # If T = 0 or v = 0, then assuming zero to avoid singularity
        if tt[idx_t0] == 0.0 or vv[idx_t0] == 0.0:
            continue
        # Creating indices of neighbouring points
        for idx in range(2):
            nbrs[idx] = idx_t0 + drxns[idx]

        # Loop over neighbourning points to find up-wind direction
        fdt = np.zeros(2)
        order = np.zeros(2, dtype=int)
        for idx, nb in enumerate(nbrs):
            # If point is outside the domain skip it
            if nb < 0 or nb >= nx:
                continue
            if vv[nb] > 0.0:
                order[idx] = 1
                fdt[idx] = drxns[idx] * (tt[nb]-tt[idx_t0]) * dx_inv
            else:
                order[idx] = 0
        # Selecting upwind derivative 
        if fdt[0] > -fdt[1] and order[0] > 0:
            ii, idrx = 0, -1
        else:
            ii, idrx = 1, 1
        # Computing t0 space derivative
        fdt0 = idrx * (tt[idx_t0 + idrx] - tt[idx_t0]) * dx_inv * dx_inv
        delta_tt[idx_t0] += (2.0 * fdt0 * delta_tt[idx_t0 + idrx] - idrx * delta_v_scaled[idx_t0]) / (2.0 * fdt0)
    return

# %%
def select_upwind_der(tt, idx_t0, vv, dx_inv):
    nbrs = np.zeros(2, dtype=int)
    drxns = [-1, 1]
    # Creating indices of neighbouring points
    for idx in range(2):
        nbrs[idx] = idx_t0 + drxns[idx]

    # Loop over neighbourning points to find up-wind direction
    fdt = np.zeros(2)
    order = np.zeros(2, dtype=int)
    for idx, nb in enumerate(nbrs):
        # If point is outside the domain skip it
        if nb < 0 or nb >= nx:
            continue
        if vv[nb] > 0.0:
            order[idx] = 1
            fdt[idx] = drxns[idx] * (tt[nb]-tt[idx_t0]) * dx_inv
        else:
            order[idx] = 0
    # Selecting upwind derivative 
    if fdt[0] > -fdt[1] and order[0] > 0:
        idrx = -1
    else:
        idrx = 1
    return idrx, order
            
def FMM_tt_lin_adj(delta_v, delta_tt, vv, tt, dx):
    """Fast-marching method linearized adjoint in 1D"""
    nx = delta_v.shape[0]
    dx_inv = 1.0 / dx
    tt_idx = np.arange(nx)
    # Sorting traveltime in descending order
    tt_idx = sorting(tt, tt_idx, ordering="d")
    
    # Looping over all indices to solve linear equations from increasing traveltime values
    for idx_t0 in tt_idx:
        # Identify the type of row (i.e., central, edge, or initial conditions)
        if tt[idx_t0] == 0.0 or vv[idx_t0] == 0.0:
            continue
        else:
            idrx0, order0 = select_upwind_der(tt, idx_t0, vv, dx_inv)
            # Computing k0 (derivative coefficient at the current index)
            k0 = 2.0 * np.sign(idrx0) * idrx0 * (tt[idx_t0 + idrx0] - tt[idx_t0]) * dx_inv * dx_inv
            nb = idx_t0 - idrx0
            # Checking if at a boundary
            if nb < 0 or nb >= nx:
                delta_v[idx_t0] =  delta_tt[idx_t0] / k0
            else:
                # Computing k1 (derivative coefficient at the forward or backgward index)
                idrx1, order1 = select_upwind_der(tt, nb, vv, dx_inv)
                k_fb = 2.0 * np.sign(idrx1) * idrx1 * (tt[nb + idrx1] - tt[nb]) * dx_inv * dx_inv
                delta_v[idx_t0] += (delta_tt[idx_t0] + k_fb * delta_v[nb]) / k0
            
    # Scaling the velocity perturbation
    delta_v[:] = 2.0 * delta_v / (vv * vv * vv)
    return

# %%
class EikonalTT_lin_1D(occamypy.Operator):

    def __init__(self, vel, tt_data, dx, SouPos, RecPos):
        """1D Eikonal-equation traveltime prediction operator"""
        # Setting Domain and Range of the operator
        self.setDomainRange(vel, tt_data)
        # Setting acquisition geometry
        self.nSou = SouPos.shape[0]
        self.nRec = RecPos.shape[0]
        self.SouPos = SouPos.copy()
        self.RecPos = RecPos.copy()
        dataShape = tt_data.shape
        if dataShape[0] != self.nSou:
            raise ValueError("Number of sources inconsistent with traveltime vector (shape[0])")
        if dataShape[1] != self.nRec:
            raise ValueError("Number of receivers inconsistent with traveltime vector (shape[1])")
        self.dx = dx
        self.nx = vel.shape[0]
        # Background model
        self.vel = vel.clone()
        self.vel.copy(vel)

    def forward(self, add, model, data):
        """Forward linearized traveltime prediction"""
        self.checkDomainRange(model, data)
        if not add: 
            data.zero()
        dataNd = data.getNdArray()
        modelNd = model.getNdArray()
        vel0Nd = self.vel.getNdArray()
        # Initialization
        tt0 = np.zeros(self.nx)
        for iShot in range(self.nSou):
            ###################################
            # Computing background traveltime #
            ###################################
            # Initial conditions
            status = np.array(["u"] * self.nx) # All points are unknown
            tt0.fill(np.inf)
            trial_idx = []
            # Initial conditions
            idx = self.SouPos[iShot]
            tt0[idx] = 0.0
            status[idx] = 't' # Trial status
            trial_idx.append(idx)
            # Sorting trial time ascending order
            trial_idx = sorting(tt0, trial_idx)
            FMM_tt(tt0, vel0Nd, self.dx, status, trial_idx) 
            ###################################
            # Computing linearized traveltime #
            ###################################
            delta_tt = np.zeros(self.nx)
            FMM_tt_lin_fwd(modelNd, delta_tt, vel0Nd, tt0, self.dx)
            for iRec in range(self.nRec):
                dataNd[iShot, iRec] += delta_tt[self.RecPos[iRec]]
        return
    
    def adjoint(self, add, model, data):
        """Adjoint linearized traveltime prediction"""
        self.checkDomainRange(model, data)
        if not add: 
            model.zero()
        dataNd = data.getNdArray()
        modelNd = model.getNdArray()
        vel0Nd = self.vel.getNdArray()
        # Initialization
        tt0 = np.zeros(self.nx)
        for iShot in range(self.nSou):
            ###################################
            # Computing background traveltime #
            ###################################
            # Initial conditions
            status = np.array(["u"] * self.nx) # All points are unknown
            tt0.fill(np.inf)
            trial_idx = []
            # Initial conditions
            idx = self.SouPos[iShot]
            tt0[idx] = 0.0
            status[idx] = 't' # Trial status
            trial_idx.append(idx)
            # Sorting trial time ascending order
            trial_idx = sorting(tt0, trial_idx)
            FMM_tt(tt0, vel0Nd, self.dx, status, trial_idx) 
            ###################################
            # Computing velocity perturbation #
            ###################################
            delta_tt = np.zeros(self.nx)
            delta_v = np.zeros(self.nx)
            # Injecting traveltime to correct grid positions
            for iRec in range(self.nRec):
                delta_tt[self.RecPos[iRec]] = dataNd[iShot, iRec]
            FMM_tt_lin_adj(delta_v, delta_tt, vel0Nd, tt0, self.dx)
            modelNd[:] += delta_v
        return
    
    def set_vel(self, vel):
        """Function to set background velocity model"""
        self.vel.copy(vel)

# %% [markdown]
# Let's start by testing the adjointness of the forward and adjoint methods.

# %%
# Dot-product test for the linearized Eikonal equation in 1D
Eik1D_Lin_Op = EikonalTT_lin_1D(vv, tt_data, dx, SouPos, RecPos)
Eik1D_Lin_Op.dotTest(True)
# Out:
# Dot-product tests of forward and adjoint operators
# --------------------------------------------------
# Applying forward operator add=False
#  Runs in: 0.009997129440307617 seconds
# Applying adjoint operator add=False
#  Runs in: 0.016707181930541992 seconds
# Dot products add=False: domain=9.216393e-01 range=9.216393e-01
# Absolute error: 3.330669e-16
# Relative error: 3.613853e-16
#
# Applying forward operator add=True
#  Runs in: 0.009383916854858398 seconds
# Applying adjoint operator add=True
#  Runs in: 0.01908707618713379 seconds
# Dot products add=True: domain=1.843279e+00 range=1.843279e+00
# Absolute error: 6.661338e-16
# Relative error: 3.613853e-16
#
# -------------------------------------------------

# %% [markdown]
# The linearization error of the linearized Eikonal operator $\mathbf{F}$ should follow:
# \begin{eqnarray}
# e = \|\mathbf{f}(\mathbf{v}+\alpha\Delta\mathbf{v})-\mathbf{f}(\mathbf{v})-\alpha\mathbf{F}(\mathbf{v})\Delta\mathbf{v}\|_2=\mathcal{O}(\alpha^2) \;\rm{as}\; \alpha \to 0,
# \end{eqnarray}
# where $\alpha$ is the scale associated with the velocity perturbation $\Delta\mathbf{v}$. Let's test if this is the case for our operator.

# %%
Eik1D_NlOp = occamypy.NonlinearOperator(Eik1D_Op, Eik1D_Lin_Op, Eik1D_Lin_Op.set_vel)
alpha, err = Eik1D_NlOp.linTest(vv)
M = err[0]/(alpha[0]*alpha[0])
fig, ax = plt.subplots(figsize=(20,10))
ax.loglog(alpha,err, lw=4, label="Computed error")
ax.loglog(alpha,M*alpha*alpha, lw=3, ls="--", label="Theoretical bound")
ax.grid()
plt.xlabel("alpha")
plt.ylabel("e [s]")
plt.legend()
ax.autoscale(enable=True, axis='x', tight=True)

# %% [markdown]
# ## Eikonal traveltime tomography

# %% [markdown]
# Now that we are confident that our operators are working properly, we can set up an inversion problem. We are going to solve a bounded non-linear L2-norm problem defined as follows:
# \begin{equation}
# \phi(\mathbf{v}) = \frac{1}{2}\|\mathbf{f}(\mathbf{v}) - \pmb{\tau}_{obs}\|_2^2,\\
# \text{s.t.} \; \mathbf{v}_{l} \leq \mathbf{v} \leq \mathbf{v}_{u}
# \end{equation}

# %%
# Source/Receiver positions
SouPos = np.arange(0, nx, 150)
RecPos = np.arange(0, nx, 10)
# Data vector
tt_data = occamypy.VectorNumpy(np.zeros((SouPos.shape[0], RecPos.shape[0])))
tt_data
# Instantiating non-linear operator
Eik1D_Op = EikonalTT_1D(vv, tt_data, dx, SouPos, RecPos)
Eik1D_Op.forward(False, vv, tt_data)
Eik1D_Lin_Op = EikonalTT_lin_1D(vv, tt_data, dx, SouPos, RecPos)
Eik1D_NlOp = occamypy.NonlinearOperator(Eik1D_Op, Eik1D_Lin_Op, Eik1D_Lin_Op.set_vel)

# %% [markdown]
# Let's generated the observed data using 3 sources and receivers every 1 km.

# %%
# Creating observed data
Eik1D_Op.forward(False, vv, tt_data)
tt_data_obs = tt_data.clone()

# %%
fig = plt.figure(figsize=(20, 5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)
# Plotting first shot
ax1.scatter(RecPos*dx, tt_data_obs.getNdArray()[0,:], linewidth=4)
ax1.plot(RecPos*dx, tt_data_obs.getNdArray()[0,:], ls="--", linewidth=2)
ax1.set_ylabel("traveltime [s]")
ax1.set_xlabel("x [km]")
ax1.set_ylim([0.0, 16.0])
ax1.autoscale(enable=True, axis='x', tight=True)
ax1.grid()
# Plotting middle shot
ax2.scatter(RecPos*dx, tt_data_obs.getNdArray()[1,:], linewidth=4)
ax2.plot(RecPos*dx, tt_data_obs.getNdArray()[1,:], ls="--", linewidth=2)
ax2.set_ylabel("traveltime [s]")
ax2.set_xlabel("x [km]")
ax2.set_ylim([0.0, 16.0])
ax2.autoscale(enable=True, axis='x', tight=True)
ax2.grid()
# Plotting last shot
ax3.scatter(RecPos*dx, tt_data_obs.getNdArray()[2,:], linewidth=4)
ax3.plot(RecPos*dx, tt_data_obs.getNdArray()[2,:], ls="--", linewidth=2)
ax3.set_ylabel("traveltime [s]")
ax3.set_xlabel("x [km]")
ax3.set_ylim([0.0, 16.0])
ax3.autoscale(enable=True, axis='x', tight=True)
ax3.grid()

# %% [markdown]
# We start the inversion by assuming a velocity model in which the Gaussian anomaly is not present.

# %%
vv_init = vv.clone().set(2.0)
fig, ax = plt.subplots(figsize=(20,10))
ax.plot(x, vv.getNdArray(), lw=4, label="True")
ax.plot(x, vv_init.getNdArray(), c="red", ls="--", lw=4, label="Initial")
ax.grid()
ax.legend()
plt.xlabel("x [km]")
plt.ylabel("velocity [km/s]")
plt.ylim([1.0, 2.5])
ax.autoscale(enable=True, axis='x', tight=True)

# %% [markdown]
# Let's compare the traveltime difference between the initially predicted and observed traveltimes for each source.

# %%
# Creating initial data
Eik1D_Op.forward(False, vv_init, tt_data)

fig = plt.figure(figsize=(20, 5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)
# Plotting first shot
ax1.scatter(RecPos*dx, tt_data_obs.getNdArray()[0,:], linewidth=4)
ax1.plot(RecPos*dx, tt_data_obs.getNdArray()[0,:], ls="--", linewidth=2, label="observed data")
ax1.scatter(RecPos*dx, tt_data.getNdArray()[0,:], c="red", linewidth=4)
ax1.plot(RecPos*dx, tt_data.getNdArray()[0,:], c="red", ls="--", linewidth=2, label="initial data")
ax1.set_ylabel("traveltime [s]")
ax1.set_xlabel("x [km]")
ax1.set_ylim([0.0, 16.0])
ax1.autoscale(enable=True, axis='x', tight=True)
ax1.grid()
# Plotting middle shot
ax2.scatter(RecPos*dx, tt_data_obs.getNdArray()[1,:], linewidth=4)
ax2.plot(RecPos*dx, tt_data_obs.getNdArray()[1,:], ls="--", linewidth=2, label="observed data")
ax2.scatter(RecPos*dx, tt_data.getNdArray()[1,:], c="red",  linewidth=4)
ax2.plot(RecPos*dx, tt_data.getNdArray()[1,:], c="red", ls="--", linewidth=2, label="initial data")
ax2.set_ylabel("traveltime [s]")
ax2.set_xlabel("x [km]")
ax2.set_ylim([0.0, 16.0])
ax2.autoscale(enable=True, axis='x', tight=True)
ax2.grid()
# Plotting last shot
ax3.scatter(RecPos*dx, tt_data_obs.getNdArray()[2,:], linewidth=4)
ax3.plot(RecPos*dx, tt_data_obs.getNdArray()[2,:], ls="--", linewidth=2,label="observed data")
ax3.scatter(RecPos*dx, tt_data.getNdArray()[2,:], c="red",  linewidth=4)
ax3.plot(RecPos*dx, tt_data.getNdArray()[2,:], c="red", ls="--", linewidth=2, label="initial data")
ax3.set_ylabel("traveltime [s]")
ax3.set_xlabel("x [km]")
ax3.set_ylim([0.0, 16.0])
ax3.autoscale(enable=True, axis='x', tight=True)
ax3.grid()

# %% [markdown]
# We now solve the non-linear constrained optimization problem using the solver L-BFGS-B.

# %%
v_min = 1.0
v_max = 3.0
minBound = occamypy.VectorNumpy(np.ones(nx)*v_min)
maxBound = occamypy.VectorNumpy(np.ones(nx)*v_max)
niter = 250
Stop  = occamypy.BasicStopper(niter=niter, tolg_proj=1e-32)
# !rm -f test.txt
BFGSBsolver = occamypy.LBFGSB(Stop, m_steps=30)
# Creating problem object using Smoothing filter and Gradient mask
filt = occamypy.VectorNumpy(np.ones(15))
SmoothOp = occamypy.ConvND(vv_init, filt)
Mask = occamypy.VectorNumpy(np.zeros(nx))
Mask.getNdArray()[int(nx*0.25):int(nx*0.75)] = 1.0
SmoothOp.forward(False, Mask, Mask.clone())
Eik1D_Inv_NlOp = occamypy.NonlinearOperator(Eik1D_Op, Eik1D_Lin_Op*SmoothOp, Eik1D_Lin_Op.set_vel)
L2_tt_prob = occamypy.NonlinearLeastSquares(vv_init.clone(), tt_data_obs, Eik1D_Inv_NlOp, 
                                            minBound=minBound, maxBound=maxBound, grad_mask=Mask)

# %%
BFGSBsolver.run(L2_tt_prob, verbose=True)
# Out:
# ##########################################################################################
# Limited-memory Broyden-Fletcher-Goldfarb-Shanno with Bounds (L-BFGS-B) algorithm
# Maximum number of steps to be used for Hessian inverse estimation: 30
# Restart folder: /tmp/restart_2021-03-25T17-28-48.281653/
# ##########################################################################################
#
# iter = 000, obj = 9.36512e+00, resnorm = 4.33e+00, gradnorm = 1.08e+02, feval = 1, geval = 1
# iter = 001, obj = 3.46916e+00, resnorm = 2.63e+00, gradnorm = 6.77e+01, feval = 2, geval = 2
# iter = 002, obj = 8.95147e-01, resnorm = 1.34e+00, gradnorm = 2.91e+01, feval = 3, geval = 3
# iter = 003, obj = 4.79319e-01, resnorm = 9.79e-01, gradnorm = 6.28e+00, feval = 4, geval = 4
# iter = 004, obj = 4.49458e-01, resnorm = 9.48e-01, gradnorm = 4.90e+00, feval = 5, geval = 5
# iter = 005, obj = 3.48906e-01, resnorm = 8.35e-01, gradnorm = 4.73e+00, feval = 6, geval = 6
# iter = 006, obj = 3.13463e-01, resnorm = 7.92e-01, gradnorm = 4.47e+00, feval = 7, geval = 7
# iter = 007, obj = 2.69396e-01, resnorm = 7.34e-01, gradnorm = 7.38e+00, feval = 8, geval = 8
# iter = 008, obj = 2.35035e-01, resnorm = 6.86e-01, gradnorm = 3.48e+00, feval = 9, geval = 9
# iter = 009, obj = 1.57293e-01, resnorm = 5.61e-01, gradnorm = 1.21e+01, feval = 10, geval = 10
# iter = 010, obj = 9.05134e-02, resnorm = 4.25e-01, gradnorm = 3.13e+00, feval = 11, geval = 11
# iter = 011, obj = 8.34854e-02, resnorm = 4.09e-01, gradnorm = 1.90e+00, feval = 12, geval = 12
# iter = 012, obj = 6.96905e-02, resnorm = 3.73e-01, gradnorm = 2.81e+00, feval = 13, geval = 13
# iter = 013, obj = 6.49096e-02, resnorm = 3.60e-01, gradnorm = 1.55e+00, feval = 14, geval = 14
# iter = 014, obj = 3.84894e-02, resnorm = 2.77e-01, gradnorm = 2.06e+00, feval = 15, geval = 15
# iter = 015, obj = 3.58767e-02, resnorm = 2.68e-01, gradnorm = 1.01e+00, feval = 16, geval = 16
# iter = 016, obj = 2.93252e-02, resnorm = 2.42e-01, gradnorm = 2.08e+00, feval = 17, geval = 17
# iter = 017, obj = 2.72982e-02, resnorm = 2.34e-01, gradnorm = 9.48e-01, feval = 18, geval = 18
# iter = 018, obj = 2.61309e-02, resnorm = 2.29e-01, gradnorm = 9.52e-01, feval = 19, geval = 19
# iter = 019, obj = 2.51324e-02, resnorm = 2.24e-01, gradnorm = 8.30e-01, feval = 20, geval = 20
# iter = 020, obj = 2.39866e-02, resnorm = 2.19e-01, gradnorm = 9.28e-01, feval = 21, geval = 21
# iter = 021, obj = 2.31599e-02, resnorm = 2.15e-01, gradnorm = 7.39e-01, feval = 22, geval = 22
# iter = 022, obj = 2.18463e-02, resnorm = 2.09e-01, gradnorm = 1.02e+00, feval = 23, geval = 23
# iter = 023, obj = 2.11351e-02, resnorm = 2.06e-01, gradnorm = 6.31e-01, feval = 24, geval = 24
# iter = 024, obj = 1.50414e-02, resnorm = 1.73e-01, gradnorm = 2.24e+00, feval = 25, geval = 25
# iter = 025, obj = 1.30047e-02, resnorm = 1.61e-01, gradnorm = 8.11e-01, feval = 26, geval = 26
# iter = 026, obj = 1.26760e-02, resnorm = 1.59e-01, gradnorm = 4.43e-01, feval = 27, geval = 27
# iter = 027, obj = 1.20663e-02, resnorm = 1.55e-01, gradnorm = 6.83e-01, feval = 28, geval = 28
# iter = 028, obj = 1.18646e-02, resnorm = 1.54e-01, gradnorm = 4.60e-01, feval = 29, geval = 29
# iter = 029, obj = 1.15546e-02, resnorm = 1.52e-01, gradnorm = 4.72e-01, feval = 30, geval = 30
# iter = 030, obj = 1.12446e-02, resnorm = 1.50e-01, gradnorm = 4.91e-01, feval = 31, geval = 31
# iter = 031, obj = 1.10291e-02, resnorm = 1.49e-01, gradnorm = 3.86e-01, feval = 32, geval = 32
# iter = 032, obj = 9.36098e-03, resnorm = 1.37e-01, gradnorm = 1.05e+00, feval = 33, geval = 33
# iter = 033, obj = 8.94949e-03, resnorm = 1.34e-01, gradnorm = 5.61e-01, feval = 34, geval = 34
# iter = 034, obj = 8.74561e-03, resnorm = 1.32e-01, gradnorm = 3.33e-01, feval = 35, geval = 35
# iter = 035, obj = 2.69005e-03, resnorm = 7.33e-02, gradnorm = 5.57e-01, feval = 36, geval = 36
# iter = 036, obj = 2.54341e-03, resnorm = 7.13e-02, gradnorm = 1.74e-01, feval = 37, geval = 37
# iter = 037, obj = 2.38835e-03, resnorm = 6.91e-02, gradnorm = 3.72e-01, feval = 38, geval = 38
# iter = 038, obj = 2.32105e-03, resnorm = 6.81e-02, gradnorm = 1.64e-01, feval = 39, geval = 39
# iter = 039, obj = 2.17797e-03, resnorm = 6.60e-02, gradnorm = 3.43e-01, feval = 40, geval = 40
# iter = 040, obj = 2.12131e-03, resnorm = 6.51e-02, gradnorm = 1.61e-01, feval = 41, geval = 41
# iter = 041, obj = 2.05156e-03, resnorm = 6.41e-02, gradnorm = 2.77e-01, feval = 42, geval = 42
# iter = 042, obj = 2.00947e-03, resnorm = 6.34e-02, gradnorm = 1.43e-01, feval = 43, geval = 43
# iter = 043, obj = 1.45268e-03, resnorm = 5.39e-02, gradnorm = 3.26e-01, feval = 44, geval = 44
# iter = 044, obj = 1.40530e-03, resnorm = 5.30e-02, gradnorm = 1.35e-01, feval = 45, geval = 45
# iter = 045, obj = 1.37776e-03, resnorm = 5.25e-02, gradnorm = 1.71e-01, feval = 46, geval = 46
# iter = 046, obj = 1.35624e-03, resnorm = 5.21e-02, gradnorm = 1.14e-01, feval = 47, geval = 47
# iter = 047, obj = 1.28372e-03, resnorm = 5.07e-02, gradnorm = 3.29e-01, feval = 48, geval = 48
# iter = 048, obj = 1.23566e-03, resnorm = 4.97e-02, gradnorm = 1.19e-01, feval = 49, geval = 49
# iter = 049, obj = 1.20703e-03, resnorm = 4.91e-02, gradnorm = 1.64e-01, feval = 50, geval = 50
# iter = 050, obj = 1.18672e-03, resnorm = 4.87e-02, gradnorm = 1.15e-01, feval = 51, geval = 51
# iter = 051, obj = 1.15844e-03, resnorm = 4.81e-02, gradnorm = 1.60e-01, feval = 52, geval = 52
# iter = 052, obj = 1.13910e-03, resnorm = 4.77e-02, gradnorm = 1.12e-01, feval = 53, geval = 53
# iter = 053, obj = 1.11167e-03, resnorm = 4.72e-02, gradnorm = 1.61e-01, feval = 54, geval = 54
# iter = 054, obj = 1.09288e-03, resnorm = 4.68e-02, gradnorm = 1.07e-01, feval = 55, geval = 55
# iter = 055, obj = 1.06323e-03, resnorm = 4.61e-02, gradnorm = 1.81e-01, feval = 56, geval = 56
# iter = 056, obj = 1.04281e-03, resnorm = 4.57e-02, gradnorm = 9.91e-02, feval = 57, geval = 57
# iter = 057, obj = 1.00043e-03, resnorm = 4.47e-02, gradnorm = 2.13e-01, feval = 58, geval = 58
# iter = 058, obj = 9.75713e-04, resnorm = 4.42e-02, gradnorm = 8.98e-02, feval = 59, geval = 59
# iter = 059, obj = 8.06236e-04, resnorm = 4.02e-02, gradnorm = 3.26e-01, feval = 60, geval = 60
# iter = 060, obj = 7.59228e-04, resnorm = 3.90e-02, gradnorm = 9.01e-02, feval = 61, geval = 61
# iter = 061, obj = 7.46048e-04, resnorm = 3.86e-02, gradnorm = 1.24e-01, feval = 62, geval = 62
# iter = 062, obj = 7.34959e-04, resnorm = 3.83e-02, gradnorm = 8.49e-02, feval = 63, geval = 63
# iter = 063, obj = 7.20737e-04, resnorm = 3.80e-02, gradnorm = 1.31e-01, feval = 64, geval = 64
# iter = 064, obj = 7.09446e-04, resnorm = 3.77e-02, gradnorm = 8.04e-02, feval = 65, geval = 65
# iter = 065, obj = 6.93516e-04, resnorm = 3.72e-02, gradnorm = 1.45e-01, feval = 66, geval = 66
# iter = 066, obj = 6.81279e-04, resnorm = 3.69e-02, gradnorm = 7.41e-02, feval = 67, geval = 67
# iter = 067, obj = 6.56840e-04, resnorm = 3.62e-02, gradnorm = 1.86e-01, feval = 68, geval = 68
# iter = 068, obj = 6.39703e-04, resnorm = 3.58e-02, gradnorm = 6.75e-02, feval = 69, geval = 69
# iter = 069, obj = 4.56083e-04, resnorm = 3.02e-02, gradnorm = 3.11e-01, feval = 70, geval = 70
# iter = 070, obj = 4.16429e-04, resnorm = 2.89e-02, gradnorm = 8.33e-02, feval = 71, geval = 71
# iter = 071, obj = 4.11284e-04, resnorm = 2.87e-02, gradnorm = 5.79e-02, feval = 72, geval = 72
# iter = 072, obj = 4.04667e-04, resnorm = 2.84e-02, gradnorm = 8.50e-02, feval = 73, geval = 73
# iter = 073, obj = 3.99625e-04, resnorm = 2.83e-02, gradnorm = 5.45e-02, feval = 74, geval = 74
# iter = 074, obj = 3.91704e-04, resnorm = 2.80e-02, gradnorm = 9.55e-02, feval = 75, geval = 75
# iter = 075, obj = 3.86242e-04, resnorm = 2.78e-02, gradnorm = 5.01e-02, feval = 76, geval = 76
# iter = 076, obj = 3.70661e-04, resnorm = 2.72e-02, gradnorm = 1.38e-01, feval = 77, geval = 77
# iter = 077, obj = 3.61663e-04, resnorm = 2.69e-02, gradnorm = 4.72e-02, feval = 78, geval = 78
# iter = 078, obj = 3.25427e-04, resnorm = 2.55e-02, gradnorm = 1.64e-01, feval = 79, geval = 79
# iter = 079, obj = 3.13668e-04, resnorm = 2.50e-02, gradnorm = 5.29e-02, feval = 80, geval = 80
# iter = 080, obj = 3.09758e-04, resnorm = 2.49e-02, gradnorm = 6.36e-02, feval = 81, geval = 81
# iter = 081, obj = 3.06329e-04, resnorm = 2.48e-02, gradnorm = 4.94e-02, feval = 82, geval = 82
# iter = 082, obj = 3.02065e-04, resnorm = 2.46e-02, gradnorm = 6.81e-02, feval = 83, geval = 83
# iter = 083, obj = 2.98648e-04, resnorm = 2.44e-02, gradnorm = 4.60e-02, feval = 84, geval = 84
# iter = 084, obj = 2.93443e-04, resnorm = 2.42e-02, gradnorm = 7.90e-02, feval = 85, geval = 85
# iter = 085, obj = 2.89658e-04, resnorm = 2.41e-02, gradnorm = 4.22e-02, feval = 86, geval = 86
# iter = 086, obj = 2.79828e-04, resnorm = 2.37e-02, gradnorm = 1.15e-01, feval = 87, geval = 87
# iter = 087, obj = 2.73558e-04, resnorm = 2.34e-02, gradnorm = 3.93e-02, feval = 88, geval = 88
# iter = 088, obj = 2.17045e-04, resnorm = 2.08e-02, gradnorm = 1.58e-01, feval = 89, geval = 89
# iter = 089, obj = 2.06663e-04, resnorm = 2.03e-02, gradnorm = 4.92e-02, feval = 90, geval = 90
# iter = 090, obj = 2.04537e-04, resnorm = 2.02e-02, gradnorm = 3.97e-02, feval = 91, geval = 91
# iter = 091, obj = 2.01951e-04, resnorm = 2.01e-02, gradnorm = 4.92e-02, feval = 92, geval = 92
# iter = 092, obj = 1.99884e-04, resnorm = 2.00e-02, gradnorm = 3.84e-02, feval = 93, geval = 93
# iter = 093, obj = 1.97190e-04, resnorm = 1.99e-02, gradnorm = 5.08e-02, feval = 94, geval = 94
# iter = 094, obj = 1.95147e-04, resnorm = 1.98e-02, gradnorm = 3.67e-02, feval = 95, geval = 95
# iter = 095, obj = 1.92158e-04, resnorm = 1.96e-02, gradnorm = 5.42e-02, feval = 96, geval = 96
# iter = 096, obj = 1.90069e-04, resnorm = 1.95e-02, gradnorm = 3.45e-02, feval = 97, geval = 97
# iter = 097, obj = 1.86199e-04, resnorm = 1.93e-02, gradnorm = 6.23e-02, feval = 98, geval = 98
# iter = 098, obj = 1.83842e-04, resnorm = 1.92e-02, gradnorm = 3.20e-02, feval = 99, geval = 99
# iter = 099, obj = 1.75517e-04, resnorm = 1.87e-02, gradnorm = 8.56e-02, feval = 100, geval = 100
# iter = 100, obj = 1.71909e-04, resnorm = 1.85e-02, gradnorm = 2.99e-02, feval = 101, geval = 101
# iter = 101, obj = 1.54099e-04, resnorm = 1.76e-02, gradnorm = 1.54e-01, feval = 102, geval = 102
# iter = 102, obj = 1.44393e-04, resnorm = 1.70e-02, gradnorm = 4.34e-02, feval = 103, geval = 103
# iter = 103, obj = 1.42954e-04, resnorm = 1.69e-02, gradnorm = 3.10e-02, feval = 104, geval = 104
# iter = 104, obj = 1.41099e-04, resnorm = 1.68e-02, gradnorm = 4.58e-02, feval = 105, geval = 105
# iter = 105, obj = 1.39651e-04, resnorm = 1.67e-02, gradnorm = 2.89e-02, feval = 106, geval = 106
# iter = 106, obj = 1.37238e-04, resnorm = 1.66e-02, gradnorm = 5.47e-02, feval = 107, geval = 107
# iter = 107, obj = 1.35530e-04, resnorm = 1.65e-02, gradnorm = 2.67e-02, feval = 108, geval = 108
# iter = 108, obj = 1.30045e-04, resnorm = 1.61e-02, gradnorm = 8.62e-02, feval = 109, geval = 109
# iter = 109, obj = 1.26671e-04, resnorm = 1.59e-02, gradnorm = 2.58e-02, feval = 110, geval = 110
# iter = 110, obj = 1.20408e-04, resnorm = 1.55e-02, gradnorm = 7.84e-02, feval = 111, geval = 111
# iter = 111, obj = 1.17520e-04, resnorm = 1.53e-02, gradnorm = 2.49e-02, feval = 112, geval = 112
# iter = 112, obj = 1.13810e-04, resnorm = 1.51e-02, gradnorm = 7.28e-02, feval = 113, geval = 113
# iter = 113, obj = 1.11324e-04, resnorm = 1.49e-02, gradnorm = 2.34e-02, feval = 114, geval = 114
# iter = 114, obj = 9.13791e-05, resnorm = 1.35e-02, gradnorm = 1.01e-01, feval = 115, geval = 115
# iter = 115, obj = 8.71134e-05, resnorm = 1.32e-02, gradnorm = 3.12e-02, feval = 116, geval = 116
# iter = 116, obj = 8.63004e-05, resnorm = 1.31e-02, gradnorm = 2.40e-02, feval = 117, geval = 117
# iter = 117, obj = 8.52397e-05, resnorm = 1.31e-02, gradnorm = 3.24e-02, feval = 118, geval = 118
# iter = 118, obj = 8.44336e-05, resnorm = 1.30e-02, gradnorm = 2.25e-02, feval = 119, geval = 119
# iter = 119, obj = 8.31212e-05, resnorm = 1.29e-02, gradnorm = 3.71e-02, feval = 120, geval = 120
# iter = 120, obj = 8.22323e-05, resnorm = 1.28e-02, gradnorm = 2.10e-02, feval = 121, geval = 121
# iter = 121, obj = 8.01253e-05, resnorm = 1.27e-02, gradnorm = 4.71e-02, feval = 122, geval = 122
# iter = 122, obj = 7.89386e-05, resnorm = 1.26e-02, gradnorm = 1.93e-02, feval = 123, geval = 123
# iter = 123, obj = 6.04708e-05, resnorm = 1.10e-02, gradnorm = 8.51e-02, feval = 124, geval = 124
# iter = 124, obj = 5.74640e-05, resnorm = 1.07e-02, gradnorm = 2.49e-02, feval = 125, geval = 125
# iter = 125, obj = 5.69497e-05, resnorm = 1.07e-02, gradnorm = 1.89e-02, feval = 126, geval = 126
# iter = 126, obj = 5.62492e-05, resnorm = 1.06e-02, gradnorm = 2.61e-02, feval = 127, geval = 127
# iter = 127, obj = 5.57344e-05, resnorm = 1.06e-02, gradnorm = 1.78e-02, feval = 128, geval = 128
# iter = 128, obj = 5.48732e-05, resnorm = 1.05e-02, gradnorm = 2.95e-02, feval = 129, geval = 129
# iter = 129, obj = 5.43129e-05, resnorm = 1.04e-02, gradnorm = 1.66e-02, feval = 130, geval = 130
# iter = 130, obj = 5.27550e-05, resnorm = 1.03e-02, gradnorm = 3.95e-02, feval = 131, geval = 131
# iter = 131, obj = 5.19467e-05, resnorm = 1.02e-02, gradnorm = 1.53e-02, feval = 132, geval = 132
# iter = 132, obj = 2.25117e-05, resnorm = 6.71e-03, gradnorm = 2.13e-02, feval = 133, geval = 133
# iter = 133, obj = 2.22563e-05, resnorm = 6.67e-03, gradnorm = 1.12e-02, feval = 134, geval = 134
# iter = 134, obj = 2.20424e-05, resnorm = 6.64e-03, gradnorm = 1.37e-02, feval = 135, geval = 135
# iter = 135, obj = 2.18854e-05, resnorm = 6.62e-03, gradnorm = 9.91e-03, feval = 136, geval = 136
# iter = 136, obj = 2.13814e-05, resnorm = 6.54e-03, gradnorm = 2.35e-02, feval = 137, geval = 137
# iter = 137, obj = 2.11281e-05, resnorm = 6.50e-03, gradnorm = 1.03e-02, feval = 138, geval = 138
# iter = 138, obj = 2.08506e-05, resnorm = 6.46e-03, gradnorm = 1.47e-02, feval = 139, geval = 139
# iter = 139, obj = 2.06927e-05, resnorm = 6.43e-03, gradnorm = 9.49e-03, feval = 140, geval = 140
# iter = 140, obj = 1.99898e-05, resnorm = 6.32e-03, gradnorm = 2.20e-02, feval = 141, geval = 141
# iter = 141, obj = 1.97495e-05, resnorm = 6.28e-03, gradnorm = 9.32e-03, feval = 142, geval = 142
# iter = 142, obj = 1.92795e-05, resnorm = 6.21e-03, gradnorm = 2.28e-02, feval = 143, geval = 143
# iter = 143, obj = 1.90411e-05, resnorm = 6.17e-03, gradnorm = 9.72e-03, feval = 144, geval = 144
# iter = 144, obj = 1.87869e-05, resnorm = 6.13e-03, gradnorm = 1.43e-02, feval = 145, geval = 145
# iter = 145, obj = 1.86439e-05, resnorm = 6.11e-03, gradnorm = 8.85e-03, feval = 146, geval = 146
# iter = 146, obj = 1.77648e-05, resnorm = 5.96e-03, gradnorm = 2.39e-02, feval = 147, geval = 147
# iter = 147, obj = 1.75027e-05, resnorm = 5.92e-03, gradnorm = 9.40e-03, feval = 148, geval = 148
# iter = 148, obj = 1.73080e-05, resnorm = 5.88e-03, gradnorm = 1.35e-02, feval = 149, geval = 149
# iter = 149, obj = 1.71824e-05, resnorm = 5.86e-03, gradnorm = 8.36e-03, feval = 150, geval = 150
# iter = 150, obj = 1.62335e-05, resnorm = 5.70e-03, gradnorm = 3.32e-02, feval = 151, geval = 151
# iter = 151, obj = 1.57933e-05, resnorm = 5.62e-03, gradnorm = 1.20e-02, feval = 152, geval = 152
# iter = 152, obj = 1.56815e-05, resnorm = 5.60e-03, gradnorm = 8.16e-03, feval = 153, geval = 153
# iter = 153, obj = 1.53170e-05, resnorm = 5.53e-03, gradnorm = 1.96e-02, feval = 154, geval = 154
# iter = 154, obj = 1.51346e-05, resnorm = 5.50e-03, gradnorm = 8.14e-03, feval = 155, geval = 155
# iter = 155, obj = 1.48180e-05, resnorm = 5.44e-03, gradnorm = 1.60e-02, feval = 156, geval = 156
# iter = 156, obj = 1.46798e-05, resnorm = 5.42e-03, gradnorm = 7.61e-03, feval = 157, geval = 157
# iter = 157, obj = 1.37266e-05, resnorm = 5.24e-03, gradnorm = 3.35e-02, feval = 158, geval = 158
# iter = 158, obj = 1.32794e-05, resnorm = 5.15e-03, gradnorm = 1.16e-02, feval = 159, geval = 159
# iter = 159, obj = 1.31856e-05, resnorm = 5.14e-03, gradnorm = 7.21e-03, feval = 160, geval = 160
# iter = 160, obj = 1.26486e-05, resnorm = 5.03e-03, gradnorm = 2.42e-02, feval = 161, geval = 161
# iter = 161, obj = 1.24024e-05, resnorm = 4.98e-03, gradnorm = 8.83e-03, feval = 162, geval = 162
# iter = 162, obj = 1.23101e-05, resnorm = 4.96e-03, gradnorm = 8.12e-03, feval = 163, geval = 163
# iter = 163, obj = 1.21975e-05, resnorm = 4.94e-03, gradnorm = 1.09e-02, feval = 164, geval = 164
# iter = 164, obj = 1.21051e-05, resnorm = 4.92e-03, gradnorm = 7.83e-03, feval = 165, geval = 165
# iter = 165, obj = 1.19849e-05, resnorm = 4.90e-03, gradnorm = 1.16e-02, feval = 166, geval = 166
# iter = 166, obj = 1.18907e-05, resnorm = 4.88e-03, gradnorm = 7.47e-03, feval = 167, geval = 167
# iter = 167, obj = 1.17515e-05, resnorm = 4.85e-03, gradnorm = 1.29e-02, feval = 168, geval = 168
# iter = 168, obj = 1.16488e-05, resnorm = 4.83e-03, gradnorm = 7.05e-03, feval = 169, geval = 169
# iter = 169, obj = 1.14569e-05, resnorm = 4.79e-03, gradnorm = 1.58e-02, feval = 170, geval = 170
# iter = 170, obj = 1.13253e-05, resnorm = 4.76e-03, gradnorm = 6.59e-03, feval = 171, geval = 171
# iter = 171, obj = 1.08226e-05, resnorm = 4.65e-03, gradnorm = 2.67e-02, feval = 172, geval = 172
# iter = 172, obj = 1.05093e-05, resnorm = 4.58e-03, gradnorm = 6.47e-03, feval = 173, geval = 173
# iter = 173, obj = 1.02067e-05, resnorm = 4.52e-03, gradnorm = 1.81e-02, feval = 174, geval = 174
# iter = 174, obj = 1.00466e-05, resnorm = 4.48e-03, gradnorm = 6.04e-03, feval = 175, geval = 175
# iter = 175, obj = 8.80062e-06, resnorm = 4.20e-03, gradnorm = 4.02e-02, feval = 176, geval = 176
# iter = 176, obj = 8.14592e-06, resnorm = 4.04e-03, gradnorm = 9.63e-03, feval = 177, geval = 177
# iter = 177, obj = 8.08421e-06, resnorm = 4.02e-03, gradnorm = 5.73e-03, feval = 178, geval = 178
# iter = 178, obj = 7.97379e-06, resnorm = 3.99e-03, gradnorm = 1.14e-02, feval = 179, geval = 179
# iter = 179, obj = 7.90062e-06, resnorm = 3.98e-03, gradnorm = 5.31e-03, feval = 180, geval = 180
# iter = 180, obj = 7.59873e-06, resnorm = 3.90e-03, gradnorm = 1.98e-02, feval = 181, geval = 181
# iter = 181, obj = 7.42571e-06, resnorm = 3.85e-03, gradnorm = 5.32e-03, feval = 182, geval = 182
# iter = 182, obj = 7.27035e-06, resnorm = 3.81e-03, gradnorm = 1.27e-02, feval = 183, geval = 183
# iter = 183, obj = 7.18651e-06, resnorm = 3.79e-03, gradnorm = 4.91e-03, feval = 184, geval = 184
# iter = 184, obj = 4.89937e-06, resnorm = 3.13e-03, gradnorm = 3.20e-02, feval = 185, geval = 185
# iter = 185, obj = 4.50342e-06, resnorm = 3.00e-03, gradnorm = 9.90e-03, feval = 186, geval = 186
# iter = 186, obj = 4.45708e-06, resnorm = 2.99e-03, gradnorm = 3.82e-03, feval = 187, geval = 187
# iter = 187, obj = 4.37661e-06, resnorm = 2.96e-03, gradnorm = 7.82e-03, feval = 188, geval = 188
# iter = 188, obj = 4.34425e-06, resnorm = 2.95e-03, gradnorm = 3.64e-03, feval = 189, geval = 189
# iter = 189, obj = 4.22313e-06, resnorm = 2.91e-03, gradnorm = 1.12e-02, feval = 190, geval = 190
# iter = 190, obj = 4.16872e-06, resnorm = 2.89e-03, gradnorm = 4.25e-03, feval = 191, geval = 191
# iter = 191, obj = 4.14088e-06, resnorm = 2.88e-03, gradnorm = 4.55e-03, feval = 192, geval = 192
# iter = 192, obj = 4.11762e-06, resnorm = 2.87e-03, gradnorm = 4.02e-03, feval = 193, geval = 193
# iter = 193, obj = 4.08630e-06, resnorm = 2.86e-03, gradnorm = 4.85e-03, feval = 194, geval = 194
# iter = 194, obj = 4.06431e-06, resnorm = 2.85e-03, gradnorm = 3.74e-03, feval = 195, geval = 195
# iter = 195, obj = 4.01891e-06, resnorm = 2.84e-03, gradnorm = 5.90e-03, feval = 196, geval = 196
# iter = 196, obj = 3.99578e-06, resnorm = 2.83e-03, gradnorm = 3.38e-03, feval = 197, geval = 197
# iter = 197, obj = 3.53018e-06, resnorm = 2.66e-03, gradnorm = 1.27e-02, feval = 198, geval = 198
# iter = 198, obj = 3.46625e-06, resnorm = 2.63e-03, gradnorm = 5.18e-03, feval = 199, geval = 199
# iter = 199, obj = 3.44741e-06, resnorm = 2.63e-03, gradnorm = 3.11e-03, feval = 200, geval = 200
# iter = 200, obj = 3.28821e-06, resnorm = 2.56e-03, gradnorm = 9.84e-03, feval = 201, geval = 201
# iter = 201, obj = 3.24554e-06, resnorm = 2.55e-03, gradnorm = 3.63e-03, feval = 202, geval = 202
# iter = 202, obj = 3.22670e-06, resnorm = 2.54e-03, gradnorm = 3.80e-03, feval = 203, geval = 203
# iter = 203, obj = 3.20923e-06, resnorm = 2.53e-03, gradnorm = 3.42e-03, feval = 204, geval = 204
# iter = 204, obj = 3.18798e-06, resnorm = 2.53e-03, gradnorm = 4.18e-03, feval = 205, geval = 205
# iter = 205, obj = 3.17222e-06, resnorm = 2.52e-03, gradnorm = 3.09e-03, feval = 206, geval = 206
# iter = 206, obj = 3.13419e-06, resnorm = 2.50e-03, gradnorm = 6.12e-03, feval = 207, geval = 207
# iter = 207, obj = 3.11399e-06, resnorm = 2.50e-03, gradnorm = 2.87e-03, feval = 208, geval = 208
# iter = 208, obj = 2.77974e-06, resnorm = 2.36e-03, gradnorm = 1.25e-02, feval = 209, geval = 209
# iter = 209, obj = 2.71745e-06, resnorm = 2.33e-03, gradnorm = 4.47e-03, feval = 210, geval = 210
# iter = 210, obj = 2.70358e-06, resnorm = 2.33e-03, gradnorm = 2.63e-03, feval = 211, geval = 211
# iter = 211, obj = 2.56814e-06, resnorm = 2.27e-03, gradnorm = 8.88e-03, feval = 212, geval = 212
# iter = 212, obj = 2.53373e-06, resnorm = 2.25e-03, gradnorm = 3.14e-03, feval = 213, geval = 213
# iter = 213, obj = 2.52061e-06, resnorm = 2.25e-03, gradnorm = 3.10e-03, feval = 214, geval = 214
# iter = 214, obj = 2.50733e-06, resnorm = 2.24e-03, gradnorm = 2.99e-03, feval = 215, geval = 215
# iter = 215, obj = 2.49227e-06, resnorm = 2.23e-03, gradnorm = 3.73e-03, feval = 216, geval = 216
# iter = 216, obj = 2.47989e-06, resnorm = 2.23e-03, gradnorm = 2.83e-03, feval = 217, geval = 217
# iter = 217, obj = 2.46270e-06, resnorm = 2.22e-03, gradnorm = 4.14e-03, feval = 218, geval = 218
# iter = 218, obj = 2.45007e-06, resnorm = 2.21e-03, gradnorm = 2.64e-03, feval = 219, geval = 219
# iter = 219, obj = 2.42553e-06, resnorm = 2.20e-03, gradnorm = 5.23e-03, feval = 220, geval = 220
# iter = 220, obj = 2.40989e-06, resnorm = 2.20e-03, gradnorm = 2.43e-03, feval = 221, geval = 221
# iter = 221, obj = 2.31564e-06, resnorm = 2.15e-03, gradnorm = 1.08e-02, feval = 222, geval = 222
# iter = 222, obj = 2.26623e-06, resnorm = 2.13e-03, gradnorm = 2.84e-03, feval = 223, geval = 223
# iter = 223, obj = 2.25284e-06, resnorm = 2.12e-03, gradnorm = 3.38e-03, feval = 224, geval = 224
# iter = 224, obj = 2.24204e-06, resnorm = 2.12e-03, gradnorm = 2.69e-03, feval = 225, geval = 225
# iter = 225, obj = 2.22682e-06, resnorm = 2.11e-03, gradnorm = 3.66e-03, feval = 226, geval = 226
# iter = 226, obj = 2.21597e-06, resnorm = 2.11e-03, gradnorm = 2.52e-03, feval = 227, geval = 227
# iter = 227, obj = 2.19530e-06, resnorm = 2.10e-03, gradnorm = 4.40e-03, feval = 228, geval = 228
# iter = 228, obj = 2.18279e-06, resnorm = 2.09e-03, gradnorm = 2.34e-03, feval = 229, geval = 229
# iter = 229, obj = 2.13892e-06, resnorm = 2.07e-03, gradnorm = 6.36e-03, feval = 230, geval = 230
# iter = 230, obj = 2.11865e-06, resnorm = 2.06e-03, gradnorm = 2.20e-03, feval = 231, geval = 231
# iter = 231, obj = 1.94507e-06, resnorm = 1.97e-03, gradnorm = 1.42e-02, feval = 232, geval = 232
# iter = 232, obj = 1.86467e-06, resnorm = 1.93e-03, gradnorm = 3.90e-03, feval = 233, geval = 233
# iter = 233, obj = 1.85496e-06, resnorm = 1.93e-03, gradnorm = 2.11e-03, feval = 234, geval = 234
# iter = 234, obj = 1.83132e-06, resnorm = 1.91e-03, gradnorm = 5.14e-03, feval = 235, geval = 235
# iter = 235, obj = 1.81775e-06, resnorm = 1.91e-03, gradnorm = 1.97e-03, feval = 236, geval = 236
# iter = 236, obj = 1.33567e-06, resnorm = 1.63e-03, gradnorm = 9.82e-03, feval = 237, geval = 237
# iter = 237, obj = 1.29768e-06, resnorm = 1.61e-03, gradnorm = 3.10e-03, feval = 238, geval = 238
# iter = 238, obj = 1.29243e-06, resnorm = 1.61e-03, gradnorm = 1.57e-03, feval = 239, geval = 239
# iter = 239, obj = 1.26312e-06, resnorm = 1.59e-03, gradnorm = 4.09e-03, feval = 240, geval = 240
# iter = 240, obj = 1.25569e-06, resnorm = 1.58e-03, gradnorm = 1.86e-03, feval = 241, geval = 241
# iter = 241, obj = 1.25078e-06, resnorm = 1.58e-03, gradnorm = 1.81e-03, feval = 242, geval = 242
# iter = 242, obj = 1.24552e-06, resnorm = 1.58e-03, gradnorm = 1.81e-03, feval = 243, geval = 243
# iter = 243, obj = 1.24053e-06, resnorm = 1.58e-03, gradnorm = 1.83e-03, feval = 244, geval = 244
# iter = 244, obj = 1.23555e-06, resnorm = 1.57e-03, gradnorm = 1.76e-03, feval = 245, geval = 245
# iter = 245, obj = 1.23026e-06, resnorm = 1.57e-03, gradnorm = 1.90e-03, feval = 246, geval = 246
# iter = 246, obj = 1.22579e-06, resnorm = 1.57e-03, gradnorm = 1.65e-03, feval = 247, geval = 247
# iter = 247, obj = 1.21902e-06, resnorm = 1.56e-03, gradnorm = 2.22e-03, feval = 248, geval = 248
# iter = 248, obj = 1.21507e-06, resnorm = 1.56e-03, gradnorm = 1.48e-03, feval = 249, geval = 249
# iter = 249, obj = 1.18028e-06, resnorm = 1.54e-03, gradnorm = 5.31e-03, feval = 250, geval = 250
# iter = 250, obj = 1.16925e-06, resnorm = 1.53e-03, gradnorm = 2.27e-03, feval = 251, geval = 251
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Limited-memory Broyden-Fletcher-Goldfarb-Shanno with Bounds (L-BFGS-B) algorithm end
# ##########################################################################################

# %% [markdown]
# Let's see if the inversion was able to retrieve the Gaussian anomaly.

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot(x, vv.getNdArray(), lw=4, label="True")
ax.plot(x, L2_tt_prob.model.getNdArray(), c="blue", ls="--", lw=4, label="Inverted")
ax.plot(x, vv_init.getNdArray(), c="red", ls="--", lw=4, label="Initial")
ax.grid()
ax.legend()
plt.xlabel("x [km]")
plt.ylabel("velocity [km/s]")
plt.ylim([1.0, 2.5])
ax.autoscale(enable=True, axis='x', tight=True)
